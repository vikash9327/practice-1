# %% [markdown]
# # ![Screenshot%202023-08-22%20155411.jpg](attachment:Screenshot%202023-08-22%20155411.jpg)

# %%
from numpy.random import randint as ri

# %%
reg_id='data_science@xyz.com'

# %%
reg_password=123456

# %%
while True:
    u_id=input("Entere user_id-")
    password=int(input("Enter password-"))
    if u_id==reg_id and password==reg_password:
        print('Login success')
    else:
        print('Wrong password')
        forgot_password=input('Forgot password ? Y or N')
        if forgot_password=='Y':
            otp1=ri(100000,1000000,1)
            print('your OTP is-',otp1)
            user_otp=int(input('enter OTP'))
            
            if otp1==user_otp:
                print('Login success')
                break
            else:
                attempts=1
                while True:
                    if attempts ==3:
                        print('max attempt reached, try again later')
                        break
                    else:
                        attempts+=1
                        print('re-enter the OTP')
                        user_otp=int(input('Enter OTP'))
                        if otp1==user_otp:
                            print('Login success')
                            success=True
                            break
                        else:
                            continue
            if success:
                break
            else:
                continue
                
        else:
            print('re-enter the login details')
            continue
# Out:
# Entere user_id-datascience@xyz.com
# Enter password-548439
# Wrong password
# Forgot password ? Y or NY
# your OTP is- [623172]
# enter OTP9842729
# re-enter the OTP
# Enter OTP8442
# re-enter the OTP
# Enter OTP623172
# Login success
